# %% [markdown]
# # Inspecting data yijing_fixed.csv
#
# source: https://github.com/adamblvck/iching-wilhelm-dataset/blob/master/README.md

# %%
import os

# 当前工作目录
print("Current working directory:", os.getcwd())

# 列出当前目录下的所有文件和文件夹
print("\nFiles in current directory:")
print(os.listdir("."))
# Out:
# Current working directory: /Users/liuqiming/Desktop/YiVerse/destiny-lens
#
# Files in current directory:
# ['middleware.ts', '.DS_Store', '.env.local', 'app', 'postcss.config.mjs', 'node_modules', '.next', 'next-env.d.ts', 'README.md', 'tailwind.config.ts', 'components', 'public', '.gitignore', 'package-lock.json', 'package.json', 'lib', 'components.json', 'tsconfig.json', '.ipynb_checkpoints', 'data_analysis.ipynb', 'remotion.config.ts', '.git', 'eslint.config.mjs', 'next.config.ts']

# %%
print("\nFiles in 'public/' folder:")
print(os.listdir("public"))
# Out:
# Files in 'public/' folder:
# ['grand_1.mp3', 'coins', 'yijing_fixed.csv', 'yijing_original.csv', 'poem.mp3']

# %%
import pandas as pd

# 设置显示所有行和所有列
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# 读取 CSV 文件
df = pd.read_csv("public/yijing_fixed.csv")

# 显示完整的 DataFrame
df
# Out:
#     hex hex_font  binary              english  od    pinyin trad_chinese  \
# 0     1        ䷀  111111           Initiating   2      qián            乾
# 1    10        ䷉  111011          Fulfillment  15        lǚ            履
# 2    11        ䷊     111              Advance  12       tài            泰
# 3    12        ䷋  111000            Hindrance  11        pǐ            否
# 4    13        ䷌  111101       SeekingHarmony   7   tóngrén           同人
# 5    14        ䷍  101111         GreatHarvest   8     dàyǒu           大有
# 6    15        ䷎     100           Humbleness  10      qiān            謙
# 7    16        ䷏    1000              Delight   9        yù            豫
# 8    17        ䷐   11001            Following  18       suí            隨
# 9    18        ䷑  100110            Remedying  17        gǔ            蠱
# 10   19        ䷒      11          Approaching  33       lín            臨
# 11    2        ䷁       0           Responding   1       kūn            坤
# ...

# %% [markdown]
# ## Display 火风鼎
#
# ### 数据结构
# - symbolic: 解释”鼎“的意义，直白地说明这个卦所被代表的象（image）是个什么样子。
#
# **pure string:** The six lines construct the image of Ting, THE CALDRON; at the bottom are the legs, over them the belly, then come the ears (handles), and at the top the carrying rings. At the same time, the image suggests the idea of nourishment. The ting, cast of bronze, was the vessel that held the cooked viands in the temple of the ancestors and at banquets. The heads of the family served the food from the ting into the bowls of the guests. THE WELL\n\n48 likewise has the secondary meaning of giving nourishment, but rather more in relation to the people. The ting, as a utensil pertaining to a refined...
#
# - image: 《象》的第一句，加自己的一些理解注释。
#
# {'text': 'Fire over wood:\n\nThe image of THE CALDRON.\n\nThus the superior man consolidates his fate\nBy making his position correct.', 'comments': 'The fate of fire depends on wood; as long as there is wood below, the fire burns above. It is the same in human life; there is in man likewise a fate that len..."}
#
# - judgements: 原文爻前对卦的描述
#
# 'text': 'THE CALDRON. Supreme good fortune.\n\nSuccess.', 'comments': 'While THE WELL relates to the social foundation of our life, and this foundation is likened to the water that serves to nourish growing wood, the present hexagram refers to the cultural superstructure of society. Here it is the wood that serves as nourishment for the flame, the spirit..."}
# - lines: 主要解释卦辞，原文译成英文，并加上自己的解释
#
# '1': {**'text'**: 'A ting with legs upturned.\nFurthers removal of stagnating stuff.\nOne takes a concubine for the sake of her son.', **'comments'**: "No blame.\n\nIf a ting is turned upside down before being used, no harm is done-on the contrary, this clears it of refuse. A concubine's position is lowly, but because she has a son she comes to be honored. These two metaphors express the idea that in a highly developed civilization, such as that indicated by this hexagram, every person of good will can in some way or other succeed. No matter how lowly he may be, provided he is ready to purify himself, he is accepted. He attains a station in which he can prove himself fruitful in accomplishment, and as a result he gains recognition.", "2": {...}, ...},

# %%
import pandas as pd

# Expand display settings
pd.set_option('display.max_colwidth', None)  # show full text in each cell
pd.set_option('display.max_columns', None)   # show all columns
pd.set_option('display.max_rows', None)      # show all rows

# Reload the CSV if not already done
df = pd.read_csv("public/yijing_fixed.csv")

# Display the full row for "EstablishingTheNew"
print(df[df["english"] == "EstablishingTheNew"])
# Out:
#     hex hex_font  binary             english  od pinyin trad_chinese  \
# 45   50        ䷱  101110  EstablishingTheNew   3   dǐng            鼎
#
#                                                                    above  \
# 45  {'chinese': 'LI', 'symbolic': 'THE CLINGING,', 'alchemical': 'FIRE'}
#
#                                                                    below  \
# 45  {'chinese': 'SUN', 'symbolic': 'THE GENTLE,', 'alchemical': 'WIND,'}
#
# ...

# %% [markdown]
# # 城市数据库
#
# 目前所选城市：
#
# 数据标准：
